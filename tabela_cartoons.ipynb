# %% [markdown]
# <a href="https://colab.research.google.com/github/alvesmariadefatima/projetos-lab-programacao/blob/main/tabela_cartoons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(10)
data = np.random.normal(20, 50, 70)

fig = plt.figure(figsize=(10, 7))
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize=(10,7))
ax = fig.add_axes([0,0,1,1])
bp = ax.boxplot(data)
plt.show()

# %%
lancamento = [randint(1961, 1986) for i in range(10)]

# %%
score = [randint(6, 8) for i in range (10)]

# %%
plt.plot(score, lancamento)

# %%
final = ['1988', '1990', '1962', '1962', '1975', '1986', '1987', '1989', '1990', '1991']

# %%
plt.plot(lancamento, final)

# %%
pd.read_csv('cartoons.csv')
# Out:
#      Unnamed: 0                             cartoon_names  release_date  \
# 0             0                                 Yogi Bear          1961
# 1             1                    The New Yogi Bear Show          1988
# 2             2                The Huckleberry Hound Show          1958
# 3             3                         Popeye the Sailor          1960
# 4             4                       The Bugs Bunny Show          1960
# ..          ...                                       ...           ...
# 217         217                         Inspecteur Gadget          1983
# 218         218          Dora and Friends: Into the City!          2014
# 219         219                     The Ollie & Moon Show          2017
# 220         220  Whisker Haven Tales with the Palace Pets          2015
# 221         221                       Pee-wee's Playhouse          1986
#
#      end_date           genre  imdb_score
# 0      1988.0      An-Com-Fam         6.6
# ...
